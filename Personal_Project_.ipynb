# %% [markdown]
# 1. Import dataset with the name fifa19.csv sent to you and show the frist 30 rows
#
# 2. Write a code to show all the columns
#
# 3. Write a code to show the 15 eldest players
#
# 4. Write a code to show the 5 youngest players
#
# 5. Who is the youngest and eldest Argentine player?
#
# 6. Delete the Unnamed column
#
# 7. How many Manchester city players are there?
#
# 8. Which players has the hoghest and lowest Release Clause?
#
# 9. Rename the Overall column to Overall_rating
#
# 10. Do you think that the Age of the players affects their Overall_rating?
#
# 11. Find the top 20 players according to their overall rating and plot a bar chart to show this (Remember to name the axes and give it a title "Top 20 players")
#
# 12. Find the country with the highest number of players and show 5 countries with the highest number of players using a bar chart (Remember to name the axes and give it a title "Highest number of players by country")
#
# 13. Find the club with the highest overall ratings of players, show the 10 best clubs using this rating. (Remember to name the axes and give it a title "Top 20 clubs")
#
# 14. Find the top 10 countries with best players using their Overall_rating and show it in a visualisation (Remember to name the axes and give it a title "Top 10 countries")
#
# 15. Find the top 10 most expensive players based on their Value
#
# 16. Find the top 5 players with great shot power
#
# 17. Find the top 5 players with best long passes

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
fifa = pd.read_csv('fifa19.csv')
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# 15 Eldest players 
fifa.sort_values(by='Age', ascending=False).head(15)
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 4741         4741  140029         O. Pérez   45
# 18183       18183   53748    K. Pilkington   44
# 17726       17726   51963        T. Warner   44
# 10545       10545  140183      S. Narazaki   42
# 7225         7225  142998         C. Muñoz   41
# 1120         1120  156092        J. Villar   41
# 12192       12192  208927     H. Sulaimani   41
# 15426       15426   18745         M. Tyler   41
# 4228         4228    3665         B. Nivet   41
# 10356       10356   49511         F. Kippe   40
# 16264       16264   28157  P. van der Vlag   40
# 9484         9484  176540      B. Castillo   40
# 4187         4187  156483     C. Lucchetti   40
# 2821         2821  232543       S. Bertoli   40
# 3550         3550   29552      S. Nakamura   40
#
#                                                 Photo        Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png             Mexico
# ...

# %%
fifa[['Name', 'Aggression']].sort_values(by='Aggression', ascending=False).head()
# Out:
#              Name  Aggression
# 1948   B. Pearson        95.0
# 9512   D. Erdmann        94.0
# 940    Gazzolisco        94.0
# 16919     D. Pipe        94.0
# 4037    J. Garner        94.0

# %%
# 5 youngest players 

fifa[['Name', 'Age']].sort_values(by='Age', ascending=True).head(5)
# Out:
#               Name  Age
# 18206    G. Nugent   16
# 17743    J. Olstad   16
# 13293  H. Massengo   16
# 16081  J. Italiano   16
# 18166     N. Ayéva   16

# %%
fifa.Nationality
# Out:
# 0        Argentina
# 1         Portugal
# 2           Brazil
# 3            Spain
# 4          Belgium
#            ...
# 18202      England
# 18203       Sweden
# 18204      England
# 18205      England
# 18206      England
# Name: Nationality, Length: 18207, dtype: object

# %%
# Youngest and oldest Argentine player

a = fifa[fifa['Nationality'] =="Argentina"].sort_values(by='Age', ascending=False).head(1)
a
# Out:
#       Unnamed: 0      ID      Name  Age  \
# 7225        7225  142998  C. Muñoz   41
#
#                                                Photo Nationality  \
# 7225  https://cdn.sofifa.org/players/4/19/142998.png   Argentina
#
#                                      Flag  Overall  Potential  \
# 7225  https://cdn.sofifa.org/flags/52.png       68         68
#
#                               Club  ... Composure Marking StandingTackle  \
# 7225  CD Universidad de Concepción  ...      62.0    18.0           14.0
#
#       SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes  \
# 7225           19.0     67.0        65.0       68.0           71.0       68.0
#
#      Release Clause
# 7225           €84K
#
# [1 rows x 89 columns]

# %%
#Oldest Argentune player

a[['Name', 'Age', 'Nationality']]
# Out:
#           Name  Age Nationality
# 7225  C. Muñoz   41   Argentina

# %%
#Youngest Argentine player

b = fifa[fifa['Nationality']=='Argentina'].sort_values(by='Age', ascending=True).head(1)
b
# Out:
#        Unnamed: 0      ID      Name  Age  \
# 17177       17177  242074  R. Gómez   16
#
#                                                 Photo Nationality  \
# 17177  https://cdn.sofifa.org/players/4/19/242074.png   Argentina
#
#                                       Flag  Overall  Potential  \
# 17177  https://cdn.sofifa.org/flags/52.png       55         76
#
#                       Club  ... Composure Marking StandingTackle  \
# 17177  Belgrano de Córdoba  ...      46.0    26.0           35.0
#
#        SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning  \
# 17177           32.0      7.0        13.0       14.0           13.0
#
#       GKReflexes Release Clause
# 17177        6.0          €466K
#
# [1 rows x 89 columns]

# %%
#So, the Youngest Argentine player is
b[['Name', 'Nationality', 'Age']]
# Out:
#            Name Nationality  Age
# 17177  R. Gómez   Argentina   16

# %%
#Deleting the 'Unnamed: 0' column
fifa.drop(['Unnamed: 0'], axis=1, inplace=True)
fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
#Total number of Manchester City players 
ManU = fifa[fifa['Club'] == 'Manchester City']
ManU
# Out:
#            ID                Name  Age  \
# 4      192985        K. De Bruyne   27
# 13     168542         David Silva   32
# 23     153079           S. Agüero   30
# 55     222492             L. Sané   22
# 56     218667      Bernardo Silva   23
# 57     210257             Ederson   24
# 60     202652         R. Sterling   23
# 75     135507         Fernandinho   33
# 84     204485           R. Mahrez   27
# 89     192366         N. Otamendi   30
# 107    139720          V. Kompany   32
# 113    212218          A. Laporte   24
# 135    188377           K. Walker   28
# 136    186942         I. Gündoğan   27
# 156    230666       Gabriel Jesus   21
# 182    203574           J. Stones   24
# 352    204884            B. Mendy   23
# 514    183427            F. Delph   28
# 645    199304              Danilo   26
# 871    174543            C. Bravo   35
# 1304   190531          E. Mangala   27
# 2903   237692            P. Foden   18
# 4652   227813        O. Zinchenko   21
# ...

# %%
#Total number of Manchester City players in figures 
ManU.Club.count()
# Out:
# 33

# %%
fifa.Value
# Out:
# 0        €110.5M
# 1           €77M
# 2        €118.5M
# 3           €72M
# 4          €102M
#           ...
# 18202       €60K
# 18203       €60K
# 18204       €60K
# 18205       €60K
# 18206       €60K
# Name: Value, Length: 18207, dtype: object

# %%
#8. 
# fifa.Value = fifa['Value'].str.replace('[\€\.\"M"\"K"]', '')
# fifa.Value

# %%
# fifa.Value = fifa.Value.str.replace('[\€\.\"M"\"K"]', '').astype(int)
# fifa.Value

# %%
fifa.Value
# Out:
# 0        €110.5M
# 1           €77M
# 2        €118.5M
# 3           €72M
# 4          €102M
#           ...
# 18202       €60K
# 18203       €60K
# 18204       €60K
# 18205       €60K
# 18206       €60K
# Name: Value, Length: 18207, dtype: object

# %%
fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
fifa[['Name', 'Value', 'Aggression', 'Composure']].head()
# Out:
#                 Name    Value  Aggression  Composure
# 0           L. Messi  €110.5M        48.0       96.0
# 1  Cristiano Ronaldo     €77M        63.0       95.0
# 2          Neymar Jr  €118.5M        56.0       94.0
# 3             De Gea     €72M        38.0       68.0
# 4       K. De Bruyne    €102M        76.0       88.0

# %%
fifa.Value.count()
# Out:
# 18207

# %%
fifa[['Name', 'Value', 'Aggression', 'Composure']].head()
# Out:
#                 Name    Value  Aggression  Composure
# 0           L. Messi  €110.5M        48.0       96.0
# 1  Cristiano Ronaldo     €77M        63.0       95.0
# 2          Neymar Jr  €118.5M        56.0       94.0
# 3             De Gea     €72M        38.0       68.0
# 4       K. De Bruyne    €102M        76.0       88.0

# %%
fifa[['Name', 'Value']].sort_values(by='Value', ascending=False)
# Out:
#                     Name Value
# 1903        M. Gaćinović   €9M
# 1787           Joelinton   €9M
# 1584   Lucas Evangelista   €9M
# 2054          O. Kharbin   €9M
# 108                 Pepe   €9M
# ...                  ...   ...
# 8061          S. Gbohouo    €0
# 8057        D. Mendiseca    €0
# 3550         S. Nakamura    €0
# 3562           B. Méndez    €0
# 17726          T. Warner    €0
#
# [18207 rows x 2 columns]

# %%
# For the Value column; 
# - We need to first of all remove the € sign which has been removed already. 
# - We need to separate each of the values inside the column (thousands from Millions) so that we 
# can add the required number of zeros to them for accurate calculation.
# - AFter this, we will need to remove all the M and K to be able to do the calculation.

# %%
# if Value is float and it has M, then, add 5 zeros, remove both M and dot
# if value is int and it has M, then add 6 zeros
# If Value is float and it has K, then add two zeros, romove both K and dot
# If Value is int and it has K, then add three zeros 

# But all the values in fifa.Value are strings

# %%
fifa.Value.head()
# Out:
# 0    €110.5M
# 1       €77M
# 2    €118.5M
# 3       €72M
# 4      €102M
# Name: Value, dtype: object

# %%
fifa[['Name','Value', 'Wage']].sort_values(by='Value', ascending=True)
# Out:
#                     Name Value  Wage
# 12227         J. Sagredo    €0    €0
# 14218           L. Ralte    €0    €0
# 7535          M. Madisha    €0    €0
# 14368  T. Hudson-Wihongi    €0    €0
# 14369        J. Tuominen    €0    €0
# ...                  ...   ...   ...
# 1136      Carlos Eduardo   €9M  €41K
# 1135           M. Fabián   €9M  €36K
# 1133             Sidcley   €9M   €1K
# 1154          C. Piccini   €9M  €29K
# 400         L. Fabiański   €9M  €70K
#
# [18207 rows x 3 columns]

# %%
fifa.Value.count()
# Out:
# 18207

# %%
fifa.Age.sum()
# Out:
# 457400

# %%
fifa.Value.sort_values(ascending=True)
# Out:
# 12227     €0
# 14218     €0
# 7535      €0
# 14368     €0
# 14369     €0
#         ...
# 1136     €9M
# 1135     €9M
# 1133     €9M
# 1154     €9M
# 400      €9M
# Name: Value, Length: 18207, dtype: object

# %%
fifa.Value
# Out:
# 0        €110.5M
# 1           €77M
# 2        €118.5M
# 3           €72M
# 4          €102M
#           ...
# 18202       €60K
# 18203       €60K
# 18204       €60K
# 18205       €60K
# 18206       €60K
# Name: Value, Length: 18207, dtype: object

# %% [markdown]
# ### The items in Value column has €, M, K, '.'
# 1. The items should be removed
#
# 2. Six zeros should be added to the items in column that has M while five zeros should be added to items that has K.
#
# 3. However, some items with M has decimals which make it six zeros which will not be correct, so
# we will remove one zero

# %%
# For the Millions, remove the M and add six zeros
fifa.Value = fifa.Value.str.replace('M', '000000')
fifa.Value
# Out:
# 0        €110.5000000
# 1           €77000000
# 2        €118.5000000
# 3           €72000000
# 4          €102000000
#              ...
# 18202            €60K
# 18203            €60K
# 18204            €60K
# 18205            €60K
# 18206            €60K
# Name: Value, Length: 18207, dtype: object

# %%
#For the thousands, remove the K and add three zeros
fifa.Value = fifa.Value.str.replace('K', '000')
fifa.Value
# Out:
# 0        €110.5000000
# 1           €77000000
# 2        €118.5000000
# 3           €72000000
# 4          €102000000
#              ...
# 18202          €60000
# 18203          €60000
# 18204          €60000
# 18205          €60000
# 18206          €60000
# Name: Value, Length: 18207, dtype: object

# %%
# #For the Millions with .1 to .9, adding six zeros will be wrong, so we have to replace the .5000000
# # with .500000
# fifa.Value = fifa.Value.str.replace('.5000000', '.500000')
# fifa.Value

# %%
fifa[['Name', 'Value']].sort_values(by='Value', ascending=True)
# Out:
#                     Name    Value
# 15884           B. Singh       €0
# 14218           L. Ralte       €0
# 14368  T. Hudson-Wihongi       €0
# 14369        J. Tuominen       €0
# 14487          J. Gulley       €0
# ...                  ...      ...
# 8239            I. Ochoa  €975000
# 8853    Pedro Chirivella  €975000
# 11579      E. Smith Rowe  €975000
# 7092           M. Tirpan  €975000
# 7969          J. Andrada  €975000
#
# [18207 rows x 2 columns]

# %%
# fifa.Value = fifa.Value.str.replace('.1000000', '.100000')
# fifa.Value

# %%
fifa.Value
# Out:
# 0        €110.5000000
# 1           €77000000
# 2        €118.5000000
# 3           €72000000
# 4          €102000000
#              ...
# 18202          €60000
# 18203          €60000
# 18204          €60000
# 18205          €60000
# 18206          €60000
# Name: Value, Length: 18207, dtype: object

# %%
fifa.Value = fifa.Value.str.replace()
